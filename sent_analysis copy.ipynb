# %%
#pip install seaborn

# %%
#pip install urllib3

# %%
#pip install requests

# %%
#pip install yfinance

# %%
#pip install pystan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import urllib3
import json
import requests
from pandas.io.json import json_normalize
from datetime import datetime
import yfinance as yf

#Install Dependencies
import tensorflow as tf
from tensorflow import keras
import torch
import re

# import nltk
# from nltk.corpus import stopwords
# from nltk import tokenize
from keras.preprocessing.text import Tokenizer


from transformers import AutoTokenizer, AutoModelForSequenceClassification
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")

#statsmodels
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold,StratifiedKFold
#Model evaluation
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import math

# %%
from  prophet import Prophet

# %%
news=pd.read_csv("/Users/Yanaorfin_1/Documents/Academy/Stock_market_sentiment_analysis/Data_set/news_11-12.2022.csv")

# %%
news_2=pd.read_csv("/Users/Yanaorfin_1/Documents/Academy/Stock_market_sentiment_analysis/Data_set/news_dec_jan.csv")

# %% [markdown]
#                                                                                     Collect data from yfinance

# %%
sp500=yf.Ticker("^GSPC")

# %%
GTHX=yf.Ticker("GTHX")

# %%
sp500.get_news()
# Out:
# [{'uuid': 'e6454cc5-85ae-36dc-b833-fad5aa87e48e',
#   'title': 'S&P 500 Wipes Out Almost 1% Rally on Fed Overhang: Markets Wrap',
#   'publisher': 'Bloomberg',
#   'link': 'https://finance.yahoo.com/news/asia-stocks-face-pressure-fed-224556015.html',
#   'providerPublishTime': 1677172222,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/spLAXTV8_0FRz4iewhD1fg--~B/aD0xMDgwO3c9MTkyMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/bloomberg_markets_842/f0a521e36f10c731c3e7b4d82b1424a6',
#      'width': 1920,
#      'height': 1080,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/.SCbyq6TKEhaFtCKbv6Y3Q--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/bloomberg_markets_842/f0a521e36f10c731c3e7b4d82b1424a6',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC']},
#  {'uuid': '08e76352-fc53-303f-82f9-ee93713d8c30',
#   'title': 'Lucid stock falls 18%, on pace for largest drop in a more than a year',
#   'publisher': 'MarketWatch',
#   'link': 'https://finance.yahoo.com/m/08e76352-fc53-303f-82f9-ee93713d8c30/lucid-stock-falls-18%25%2C-on.html',
#   'providerPublishTime': 1677171480,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/S8SCotpO9m2XQyQUIGU5dw--~B/aD02MzA7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/marketwatch.com/96d076434b2a015a3010bd2787b8c856',
#      'width': 1200,
#      'height': 630,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/FUOaXzXTWeRpF8AHxhm.PQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/marketwatch.com/96d076434b2a015a3010bd2787b8c856',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC']},
#  {'uuid': 'f9caba3f-be42-3213-a1b8-92bc55829288',
#   'title': 'Lucid Stock Drops 17% as Output Forecast Raises Concern Over Cash',
#   'publisher': 'Barrons.com',
#   'link': 'https://finance.yahoo.com/m/f9caba3f-be42-3213-a1b8-92bc55829288/lucid-stock-drops-17%25-as.html',
#   'providerPublishTime': 1677170640,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/ElJ5PXsqrF.7oG42nGHh7g--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/f5831972de52e9354cd51f71e569b8ea',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/jK2rci8fg_EvobDU1zELVg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/f5831972de52e9354cd51f71e569b8ea',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC']},
#  {'uuid': '74f1e148-38c6-4e09-8950-10de246c6ebf',
#   'title': 'Stock market news today: Stocks fall after back-to-back losses for S&P 500, Dow',
#   'publisher': 'Yahoo Finance',
#   'link': 'https://finance.yahoo.com/news/stock-market-news-today-february-23-2023-122852056.html',
#   'providerPublishTime': 1677169678,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/BpOqAsCENWQgw7ZeBtsyNg--~B/aD01NDY0O3c9ODE5MjthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2023-02/cff0db00-b2d5-11ed-97ff-094dee832d20',
#      'width': 8192,
#      'height': 5464,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/J1rk2zubzqimTVwWDxO0OQ--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-02/cff0db00-b2d5-11ed-97ff-094dee832d20',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC', '^DJI', '^IXIC']},
#  {'uuid': '4b493d7d-8dc1-3909-be53-2e24f7a7d231',
#   'title': 'Liquidity continues to drive markets amid Fed’s inflation battle',
#   'publisher': 'Yahoo Finance Video',
#   'link': 'https://finance.yahoo.com/video/liquidity-continues-drive-markets-amid-162331338.html',
#   'providerPublishTime': 1677169411,
#   'type': 'VIDEO',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/b6B9ThTZp0U5tuC14XAZOQ--~B/aD03MjA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-02/1a4d83a0-b395-11ed-be7b-36cf9991a6eb',
#      'width': 1280,
#      'height': 720,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/Y0qQGZhGLHQP3ht7jE.0cw--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://s.yimg.com/os/creatr-uploaded-images/2023-02/1a4d83a0-b395-11ed-be7b-36cf9991a6eb',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^DJI', '^GSPC', '^IXIC']},
#  {'uuid': 'babb9ad9-4f4f-3fc5-a6a9-0e57787292f9',
#   'title': 'After grim fourth quarter, investors face worst year for earnings since 2000 by this measure, says UBS',
#   'publisher': 'MarketWatch',
#   'link': 'https://finance.yahoo.com/m/babb9ad9-4f4f-3fc5-a6a9-0e57787292f9/after-grim-fourth-quarter%2C.html',
#   'providerPublishTime': 1677167040,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/pY.vLMfvbm7hW7pOgyqxIw--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/marketwatch.com/72e2f0f22024071409589d8bcfdce983',
#      'width': 1280,
#      'height': 640,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/1MF9ogTKIMiOhtyqEE9GDA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/marketwatch.com/72e2f0f22024071409589d8bcfdce983',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['^GSPC']},
#  {'uuid': 'c9452a17-dcb0-3a96-8012-78dfb09cfcd1',
#   'title': 'US STOCKS-Nvidia-led surge in chip stocks lifts Wall Street out of Fed blues',
#   'publisher': 'Reuters',
#   'link': 'https://finance.yahoo.com/news/us-stocks-nvidia-led-surge-152903867.html',
#   'providerPublishTime': 1677166143,
#   'type': 'STORY',
#   'relatedTickers': ['^GSPC', 'COMP', 'NVDA', '^DJI']},
#  {'uuid': 'c60174f6-9fe5-3008-ab93-6911a2c1ed38',
#   'title': '3 Medical Instruments Stocks to Buy Amid Improving Industry Trends',
#   'publisher': 'Zacks',
#   'link': 'https://finance.yahoo.com/news/3-medical-instruments-stocks-buy-152703774.html',
#   'providerPublishTime': 1677166023,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/UpEbnpQXp89kdVJQCodgsg--~B/aD00MDA7dz02MzU7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/zacks.com/fbb9903a8d1b847919d491b1319d2545',
#      'width': 635,
#      'height': 400,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/_8wDxN8WGlGvzAEKe5nuhg--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/zacks.com/fbb9903a8d1b847919d491b1319d2545',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['EW', 'HOLX', 'IDXX', '^GSPC']}]

# %%
index_price=sp500.history(start="2022-11-01", end="2023-01-12",)

# %%
index_price_13m=sp500.history(start="2022-01-01", end="2023-01-31",)
index_price_13m.drop(labels=["Dividends","Stock Splits"],axis=1,inplace=True)
index_price_13m=index_price_13m.tz_localize(None)

# %%
index_price.drop(labels=["Dividends","Stock Splits"],axis=1,inplace=True)

# %%
index_price=index_price.tz_localize(None)

# %%
index_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 49 entries, 2022-11-01 to 2023-01-11
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    49 non-null     float64
#  1   High    49 non-null     float64
#  2   Low     49 non-null     float64
#  3   Close   49 non-null     float64
#  4   Volume  49 non-null     int64
# dtypes: float64(4), int64(1)
# memory usage: 2.3 KB

# %% [markdown]
#                                                                                     DATA WRANGLING & CLEANING

# %%
#index=pd.read_csv

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    10000 non-null  int64
#  1   title         10000 non-null  object
#  2   url           10000 non-null  object
#  3   description   10000 non-null  object
#  4   source        10000 non-null  object
#  5   tickers       10000 non-null  object
#  6   tags          10000 non-null  object
#  7   published_at  10000 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 625.1+ KB

# %%
news.drop(labels="Unnamed: 0",axis=1,inplace=True)

# %%
news_2.drop(labels="Unnamed: 0",axis=1,inplace=True)

# %%
news.isna().sum()
# Out:
# title           0
# url             0
# description     0
# source          0
# tickers         0
# tags            0
# published_at    0
# dtype: int64

# %%
sns.countplot(data=news,x="source")
# Out:
# <AxesSubplot:xlabel='source', ylabel='count'>

# %% [markdown]
#                                                                             FinBERT test

# %% [markdown]
# Test

# %%
tokens=tokenizer.encode("wells fargo maintains overweight on agilent technologies raises price target to 95.",return_tensors="pt")
tokens
# Out:
# tensor([[  101,  7051, 23054,  9319,  2058, 11179,  2006, 29003,  3372,  6786,
#          13275,  3976,  4539,  2000,  5345,  1012,   102]])

# %%
result=model(tokens)
result
# Out:
# SequenceClassifierOutput(loss=None, logits=tensor([[ 1.7195, -1.9257, -0.9715]], grad_fn=<AddmmBackward0>), hidden_states=None, attentions=None)

# %%
result.logits
# Out:
# tensor([[ 1.7195, -1.9257, -0.9715]], grad_fn=<AddmmBackward0>)

# %%
(torch.argmax(result.logits))+1
# Out:
# tensor(1)

# %% [markdown]
#                                                 Apllying Model on tittles

# %%
def sentiment_score(text):
    tokens=tokenizer.encode(text,return_tensors="pt")
    result=model(tokens)
    return int(torch.argmax(result.logits))+1

# %%
#news["sentiment_title"]=news["title"].apply(lambda x:sentiment_score(x[:512]))
#BERT (and many other transformer models) will consume 512 tokens max — truncating anything beyond this length

# %%
#news_2["sentiment_title"]=news_2["title"].apply(lambda x:sentiment_score(x[:512]))
#BERT (and many other transformer models) will consume 512 tokens max — truncating anything beyond this length

# %%
#news_2["sentiment_description"]=news_2["description"].apply(lambda x:sentiment_score(x[:512]))

# %%
#news_2.to_csv("/Users/Yanaorfin_1/Documents/Academy/Stock_market_sentiment_analysis/Data_set/news_full_2.csv")

# %%
news=pd.read_csv("/Users/Yanaorfin_1/Documents/Academy/Stock_market_sentiment_analysis/Data_set/news_full.csv")

# %%
news_2=pd.read_csv("/Users/Yanaorfin_1/Documents/Academy/Stock_market_sentiment_analysis/Data_set/news_full_2.csv")

# %%
news=news.append(news_2)
# Out:
# /var/folders/0g/qs1_nm7j3n30v6qskgpxqmd80000gn/T/ipykernel_86424/2509051536.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   news=news.append(news_2)

# %%
news["date"]=pd.to_datetime(news["published_at"]).dt.date

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             20000 non-null  int64
#  1   title                  20000 non-null  object
#  2   url                    20000 non-null  object
#  3   description            20000 non-null  object
#  4   source                 20000 non-null  object
#  5   tickers                20000 non-null  object
#  6   tags                   20000 non-null  object
#  7   published_at           20000 non-null  object
#  8   sentiment_title        20000 non-null  int64
#  9   sentiment_description  10000 non-null  float64
#  10  date                   20000 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.8+ MB

# %%
news.drop(labels="Unnamed: 0",axis=1,inplace=True)

# %%
news.reset_index(inplace=True)

# %%
news.drop(labels="index",axis=1,inplace=True)

# %%
n_subplots=2
sharey=True
fig,axs=plt.subplots(1,n_subplots,sharey=sharey)
sns.countplot(data=news,x="sentiment_title",ax=axs[0])
sns.countplot(data=news,x="sentiment_description",ax=axs[1])
# Out:
# <AxesSubplot:xlabel='sentiment_description', ylabel='count'>

# %%
#news.to_csv("/Users/Yanaorfin_1/Documents/Academy/Stock_market_sentiment_analysis/Data_set/news_full.csv")

# %%
grouped_news=news.loc[:,["date","sentiment_title","sentiment_description"]].groupby(by="date",axis=0,dropna=True,as_index=True).mean()

# %%
grouped_news.head()
# Out:
#             sentiment_title  sentiment_description
# date
# 2022-11-01         1.800000               1.646154
# 2022-11-02         1.911765               1.926471
# 2022-11-03         1.916667               1.816667
# 2022-11-04         1.843137               1.607843
# 2022-11-05         2.000000               2.000000

# %%
sns.lineplot(data=grouped_news)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
index_price.tail(1)
# Out:
#                    Open         High          Low        Close      Volume
# Date
# 2023-01-11  3932.350098  3970.070068  3928.540039  3969.610107  4303360000

# %%
full_data=index_price.join(grouped_news, how="left")

# %%
full_data.drop(labels="sentiment_description",axis=1,inplace=True)

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 49 entries, 2022-11-01 to 2023-01-11
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Open             49 non-null     float64
#  1   High             49 non-null     float64
#  2   Low              49 non-null     float64
#  3   Close            49 non-null     float64
#  4   Volume           49 non-null     int64
#  5   sentiment_title  49 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 3.7 KB

# %%
#Correlation matrix

fig,axs=plt.subplots(figsize=(8,4))

corr_data=full_data[["Volume","Open","Close","sentiment_title"]]
# hour_df=hour[["yr","season","holiday","mnth","weekday","orkingday","weathersit","temp","atemp","hum","windspeed","weather_score","casual","registered"]]
matrix_df=corr_data.corr()

# Generate a mask to onlyshow the bottom triangle
mask = np.triu(np.ones_like(matrix_df, dtype=bool))

sns.heatmap(data=matrix_df,cmap="coolwarm",vmin=-1,vmax=1,robust=True,square=False,annot=True,mask=mask)
plt.show()

# %%
fig, ax = plt.subplots(constrained_layout=True)
plt.figure()
width=.4
width2=.05

up=full_data[full_data.Close>=full_data.Open]
down=full_data[full_data.Close<full_data.Open]

col1="green"
col2="red"

plt.bar(up.index,up.Close -up.Open,width,bottom=up.Open,color=col1)
plt.bar(up.index,up.High -up.Close,width2,bottom=up.Close,color=col1)
plt.bar(up.index,up.Low -up.Open,width2,bottom=up.Open,color=col1)


plt.bar(down.index,down.Close -down.Open,width,bottom=down.Open,color=col2)
plt.bar(down.index,down.High -down.Open,width2,bottom=down.Open,color=col2)
plt.bar(down.index,down.Low -down.Close,width2,bottom=down.Close,color=col2)

plt.xticks(rotation=45,ha="right")




ax2 = ax.twinx()


ax2.plot(full_data["sentiment_title"], color='green')
ax2.tick_params(axis='y', labelcolor='green')


plt.show()

# %%
sns.lineplot(data=full_data, x="Close",y="sentiment_title")
# Out:
# <AxesSubplot:xlabel='Close', ylabel='sentiment_title'>

# %% [markdown]
#                                                                             ML Linear Regression
#                                                                 predict the price based on the sentiment score

# %% [markdown]
# Providing Data

# %%
ml_data=full_data.reset_index()

# %%
#ml_data.drop(labels="index",inplace=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/0g/qs1_nm7j3n30v6qskgpxqmd80000gn/T/ipykernel_86424/2039109577.py in <module>
# ----> 1 ml_data.drop(labels="index",inplace=True,axis=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
X=full_data[["sentiment_title"]]
y=full_data[["Close"]]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=True)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (34, 1)
# (15, 1)
# (34, 1)
# (15, 1)

# %% [markdown]
# Standartization

# %% [markdown]
# Fitting Model

# %%
lr=LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model Prediction

# %%
y_predict=lr.predict(X_test)

# %% [markdown]
# Model Evaluation

# %%
print("Inrecept is " + str(lr.intercept_))
print("R-squared value is ",lr.score(X_train,y_train))
print("Adjusted R-squared value is",r2_score(y_test, y_predict,multioutput='variance_weighted'))
print("MSE:", mean_squared_error(y_test, y_predict))
print("RMSE:",math.sqrt(mean_squared_error(y_test, y_predict)))
print("MAE:",mean_absolute_error(y_test, y_predict))
# Out:
# Inrecept is [4046.89826045]
# R-squared value is  0.054985968912599326
# Adjusted R-squared value is -0.018950710897964962
# MSE: 9718.440203333616
# RMSE: 98.58214951670315
# MAE: 85.9331722259135

# %%
y_prediction=pd.DataFrame(y_predict,columns={"predicted_values":y_predict})

# %%
#y_test.reset_index(inplace=True,drop=True)
#y_test.drop(labels="index",axis=1,inplace=True)

# %%
y_test
# Out:
#           Close
# 0   3934.379883
# 1   3821.620117
# 2   3783.219971
# 3   3969.610107
# 4   3719.889893
# 5   3770.550049
# 6   3824.139893
# 7   4019.649902
# 8   3895.080078
# 9   3995.320068
# 10  3895.750000
# 11  3829.250000
# 12  4076.570068
# 13  3878.439941
# 14  3957.629883

# %%
lr_performance=pd.concat([y_test,y_prediction],axis=1)

# %%
lr_performance.rename(columns={"Close":"actual_values"},inplace=True)

# %%
lr_performance
# Out:
#     actual_values  predicted_values
# 0     3934.379883       3911.711792
# 1     3821.620117       3925.157138
# 2     3783.219971       3908.352645
# 3     3969.610107       3941.360533
# 4     3719.889893       3892.750661
# 5     3770.550049       3898.664252
# 6     3824.139893       3926.724998
# 7     4019.649902       3931.915880
# 8     3895.080078       3948.619440
# 9     3995.320068       3915.152874
# 10    3895.750000       3911.356020
# 11    3829.250000       3936.375788
# 12    4076.570068       3912.068391
# 13    3878.439941       3946.731314
# 14    3957.629883       3928.745173

# %%
sns.lineplot(data=lr_performance)
# Out:
# <AxesSubplot:>

# %% [markdown]
#                                                                                         Time series

# %%
full_data[["Close","sentiment_title"]].plot(grid="on")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
#Augmented Dickey Fuller Test (ADF Test) - non-stationary

# ADF Test
result = adfuller(full_data["Close"], autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -2.158002571112376
# n_lags: 0.22183948229034844
# p-value: 0.22183948229034844
# Critial Values:
#    1%, -3.5745892596209488
# Critial Values:
#    5%, -2.9239543084490744
# Critial Values:
#    10%, -2.6000391840277777

# %%
# ADF Test non-stationary
result = adfuller(index_price_13m["Close"], autolag='AIC')
print(f'ADF Statistic: {result[0]}')
print(f'n_lags: {result[1]}')
print(f'p-value: {result[1]}')
for key, value in result[4].items():
    print('Critial Values:')
    print(f'   {key}, {value}')
# Out:
# ADF Statistic: -2.652761382221548
# n_lags: 0.08257533145900703
# p-value: 0.08257533145900703
# Critial Values:
#    1%, -3.4548957220044336
# Critial Values:
#    5%, -2.8723451788613157
# Critial Values:
#    10%, -2.572527778361272

# %%
full_data["Close"].plot(grid="on")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
index_price_13m["Close"].plot(grid="on")
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
#                                                                                                  Full data set

# %%
df_news_prices=news.loc[:,["date","sentiment_title","sentiment_description"]].set_index("date").join(index_price)

# %%
df_news_prices.dropna(axis=0,inplace=True)

# %%
df_news_prices.tail(1)
# Out:
#             sentiment_title  sentiment_description         Open        High  \
# 2022-12-14                2                    2.0  4015.540039  4053.76001
#
#                     Low        Close        Volume
# 2022-12-14  3965.649902  3995.320068  4.472340e+09

# %%
df_news_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9940 entries, 2022-11-01 to 2022-12-14
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sentiment_title        9940 non-null   int64
#  1   sentiment_description  9940 non-null   float64
#  2   Open                   9940 non-null   float64
#  3   High                   9940 non-null   float64
#  4   Low                    9940 non-null   float64
#  5   Close                  9940 non-null   float64
#  6   Volume                 9940 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 621.2 KB

# %%
#Correlation matrix

fig,axs=plt.subplots()

corr_data=df_news_prices[["Volume","Open","Close","sentiment_title","sentiment_description"]]
# hour_df=hour[["yr","season","holiday","mnth","weekday","orkingday","weathersit","temp","atemp","hum","windspeed","weather_score","casual","registered"]]
matrix_df=corr_data.corr()

# Generate a mask to onlyshow the bottom triangle
mask = np.triu(np.ones_like(matrix_df, dtype=bool))

sns.heatmap(data=matrix_df,cmap="coolwarm",vmin=-1,vmax=1,robust=True,square=False,annot=True,mask=mask)
plt.show()

# %% [markdown]
#                                                                                             FB Prophet

# %%
# Training model 

df_close=full_data.drop(["sentiment_title","Open","High","Low","Volume"],axis=1)
df_score=full_data.drop(["Close","Open","High","Low","Volume"],axis=1)

# %%
df_close.reset_index(inplace=True)
df_score.reset_index(inplace=True)

# %%
df_close = df_close.rename(columns = {'Date':'ds',"Close":"y"})
df_score = df_score.rename(columns = {'Date':'ds',"sentiment_title":"y"})

# %%
m=Prophet(interval_width=0.95)
model=m.fit(df_close)
# Out:
# 13:37:07 - cmdstanpy - INFO - Chain [1] start processing
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 13:37:07 - cmdstanpy - INFO - Chain [1] done processing

# %%
m2=Prophet(interval_width=0.95)
model2=m2.fit(df_score)
# Out:
# 13:37:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:07 - cmdstanpy - INFO - Chain [1] done processing
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
#Forecast "Close" price
future=m.make_future_dataframe(periods=0,freq="D")
forecest_close=m.predict(future)

# %%
#Forecast "SEntiment title" 
future2=m2.make_future_dataframe(periods=0,freq="D")
forecest_score=m2.predict(future2)

# %%
forecest_close.head(5)
# Out:
#           ds        trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 2022-11-01  2092.582391  3686.197207  3862.982455  2092.582391  2092.582391
# 1 2022-11-02  2105.506571  3688.870580  3884.143700  2105.506571  2105.506571
# 2 2022-11-03  2118.430751  3692.923658  3879.411877  2118.430751  2118.430751
# 3 2022-11-04  2131.354930  3722.469959  3910.281525  2131.354930  2131.354930
# 4 2022-11-07  2170.127469  3749.324254  3923.674368  2170.127469  2170.127469
#
#    additive_terms  additive_terms_lower  additive_terms_upper       weekly  \
# 0     1680.050632           1680.050632           1680.050632  1680.050632
# 1     1676.668176           1676.668176           1676.668176  1676.668176
# 2     1668.728313           1668.728313           1668.728313  1668.728313
# 3     1683.121339           1683.121339           1683.121339  1683.121339
# 4     1661.815295           1661.815295           1661.815295  1661.815295
#
#    weekly_lower  weekly_upper  multiplicative_terms  \
# 0   1680.050632   1680.050632                   0.0
# 1   1676.668176   1676.668176                   0.0
# 2   1668.728313   1668.728313                   0.0
# 3   1683.121339   1683.121339                   0.0
# 4   1661.815295   1661.815295                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                         0.0                         0.0  3772.633024
# 1                         0.0                         0.0  3782.174747
# 2                         0.0                         0.0  3787.159064
# 3                         0.0                         0.0  3814.476270
# 4                         0.0                         0.0  3831.942764

# %%
index_price

# %%
forecest_close.head(10)
# Out:
#           ds        trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0 2022-11-01  2092.582391  3686.197207  3862.982455  2092.582391  2092.582391
# 1 2022-11-02  2105.506571  3688.870580  3884.143700  2105.506571  2105.506571
# 2 2022-11-03  2118.430751  3692.923658  3879.411877  2118.430751  2118.430751
# 3 2022-11-04  2131.354930  3722.469959  3910.281525  2131.354930  2131.354930
# 4 2022-11-07  2170.127469  3749.324254  3923.674368  2170.127469  2170.127469
# 5 2022-11-08  2183.051649  3775.873733  3954.949328  2183.051649  2183.051649
# 6 2022-11-09  2195.975829  3785.609472  3966.490701  2195.975829  2195.975829
# 7 2022-11-10  2208.900009  3784.737171  3967.611528  2208.900009  2208.900009
# 8 2022-11-11  2221.824189  3809.473230  4000.066828  2221.824189  2221.824189
# 9 2022-11-14  2260.576199  3826.670551  4015.482779  2260.576199  2260.576199
#
#    additive_terms  additive_terms_lower  additive_terms_upper       weekly  \
# 0     1680.050632           1680.050632           1680.050632  1680.050632
# 1     1676.668176           1676.668176           1676.668176  1676.668176
# 2     1668.728313           1668.728313           1668.728313  1668.728313
# 3     1683.121339           1683.121339           1683.121339  1683.121339
# 4     1661.815295           1661.815295           1661.815295  1661.815295
# 5     1680.050632           1680.050632           1680.050632  1680.050632
# 6     1676.668176           1676.668176           1676.668176  1676.668176
# 7     1668.728313           1668.728313           1668.728313  1668.728313
# 8     1683.121339           1683.121339           1683.121339  1683.121339
# 9     1661.815295           1661.815295           1661.815295  1661.815295
#
#    weekly_lower  weekly_upper  multiplicative_terms  \
# 0   1680.050632   1680.050632                   0.0
# 1   1676.668176   1676.668176                   0.0
# 2   1668.728313   1668.728313                   0.0
# 3   1683.121339   1683.121339                   0.0
# 4   1661.815295   1661.815295                   0.0
# 5   1680.050632   1680.050632                   0.0
# 6   1676.668176   1676.668176                   0.0
# 7   1668.728313   1668.728313                   0.0
# 8   1683.121339   1683.121339                   0.0
# 9   1661.815295   1661.815295                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                         0.0                         0.0  3772.633024
# 1                         0.0                         0.0  3782.174747
# 2                         0.0                         0.0  3787.159064
# 3                         0.0                         0.0  3814.476270
# 4                         0.0                         0.0  3831.942764
# 5                         0.0                         0.0  3863.102281
# 6                         0.0                         0.0  3872.644005
# 7                         0.0                         0.0  3877.628322
# 8                         0.0                         0.0  3904.945528
# 9                         0.0                         0.0  3922.391493

# %%
plot1=m.plot(forecest_close)

# %%
plot2=m.plot_components(forecest_close)

# %%
forecest_score.head(10)
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2022-11-01  1.009516    1.336045    2.077732     1.009516     1.009516
# 1 2022-11-02  1.003100    1.497248    2.191797     1.003100     1.003100
# 2 2022-11-03  0.996684    1.455740    2.187099     0.996684     0.996684
# 3 2022-11-04  0.990268    1.436081    2.179722     0.990268     0.990268
# 4 2022-11-07  0.971021    1.428548    2.141616     0.971021     0.971021
# 5 2022-11-08  0.964605    1.306829    2.044852     0.964605     0.964605
# 6 2022-11-09  0.958189    1.409626    2.157976     0.958189     0.958189
# 7 2022-11-10  0.951773    1.405360    2.141088     0.951773     0.951773
# 8 2022-11-11  0.945357    1.367238    2.111197     0.945357     0.945357
# 9 2022-11-14  0.926109    1.367835    2.125275     0.926109     0.926109
#
#    additive_terms  additive_terms_lower  additive_terms_upper    weekly  \
# 0        0.702610              0.702610              0.702610  0.702610
# 1        0.839965              0.839965              0.839965  0.839965
# 2        0.827146              0.827146              0.827146  0.827146
# 3        0.808481              0.808481              0.808481  0.808481
# 4        0.819861              0.819861              0.819861  0.819861
# 5        0.702610              0.702610              0.702610  0.702610
# 6        0.839965              0.839965              0.839965  0.839965
# 7        0.827146              0.827146              0.827146  0.827146
# 8        0.808481              0.808481              0.808481  0.808481
# 9        0.819861              0.819861              0.819861  0.819861
#
#    weekly_lower  weekly_upper  multiplicative_terms  \
# 0      0.702610      0.702610                   0.0
# 1      0.839965      0.839965                   0.0
# 2      0.827146      0.827146                   0.0
# 3      0.808481      0.808481                   0.0
# 4      0.819861      0.819861                   0.0
# 5      0.702610      0.702610                   0.0
# 6      0.839965      0.839965                   0.0
# 7      0.827146      0.827146                   0.0
# 8      0.808481      0.808481                   0.0
# 9      0.819861      0.819861                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  1.712126
# 1                         0.0                         0.0  1.843065
# 2                         0.0                         0.0  1.823830
# 3                         0.0                         0.0  1.798749
# 4                         0.0                         0.0  1.790881
# 5                         0.0                         0.0  1.667215
# 6                         0.0                         0.0  1.798154
# 7                         0.0                         0.0  1.778919
# 8                         0.0                         0.0  1.753838
# 9                         0.0                         0.0  1.745970

# %%
plot_score1=m2.plot(forecest_score)

# %%
plot_score2=m2.plot_components(forecest_score)

# %%
forecast=forecest_close.join(forecest_score,rsuffix="_a")

# %%
forecast=forecast.loc[:,["ds","yhat","yhat_a"]]

# %%
forecast.info()
#df2['yhat'] = df2['trend'] + df2['seasonal']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      49 non-null     datetime64[ns]
#  1   yhat    49 non-null     float64
#  2   yhat_a  49 non-null     float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 1.3 KB

# %%
forecast.rename(columns={"yhat":"close","yhat_a":"sentiment_score"},inplace=True)

# %%
#Correlation matrix

fig,axs=plt.subplots(figsize=(8,4))

corr_data=forecast[["close","sentiment_score"]]

matrix_df=corr_data.corr()

# Generate a mask to onlyshow the bottom triangle
mask = np.triu(np.ones_like(matrix_df, dtype=bool))

sns.heatmap(data=matrix_df,cmap="coolwarm",vmin=-1,vmax=1,robust=True,square=False,annot=True,mask=mask)
plt.show()
